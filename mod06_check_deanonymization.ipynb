# %%
import pandas as pd
from mod06_deanonymize import load_data, link_records, deanonymization_rate
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 from mod06_deanonymize import load_data, link_records, deanonymization_rate
#
# ModuleNotFoundError: No module named 'pandas'

# %%
anon_path = "mod06_data/anonymized.csv"
aux_path = "mod06_data/auxiliary.csv"

# %% [markdown]
# ### Load and review the data

# %%
anon, aux = load_data(anon_path, aux_path)

# %%
anon.head(20)

# %% [markdown]
# ### Merge the datasets by age, gender, and zip3 and return the unique matches

# %%
matches = link_records(anon, aux)
matches.head()

# %% [markdown]
# ### Calculate the match rate

# %%
rate = deanonymization_rate(matches, anon)
print(rate)

# %% [markdown]
# # Discussion Questions

# %% [markdown]
# ### Describe your reaction to the match rate. What sources of data might be prone to privacy issues?

# %% [markdown]
# Honestly it was a little too easy to make all the people match up. It didn't seem very secure despite all the efforts to make things annonymized. This almost felt like one of the proofs from cybersecurity class used to prove why something isn't secure, or in this case doesn't have proper privacy. There are privacy issues of course in the name being so easily able to map to the people. Yet also, the company can gear things to peoples age range, just in general.
#
#
#
# I think that the concept of keeping everyones age was a tad harder to believe. This might be prone to privacy issues given that the only way to know to update the ages is around people's birthdays. This is more of a reach, but I do think it is something to think about

# %% [markdown]
# ### Provide examples of at least two other variables that could increase the match rate if included.

# %% [markdown]
# Type your answer here.
